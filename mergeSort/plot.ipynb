# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv")
df = df.sort_values("size")

# %%
df
# Out:
#     size  best   avg  worst
# 66    32    80   124     80
# 59    35    96   142     85
# 93    44   132   187    112
# 39    60   184   282    172
# 72    75   252   380    220
# ..   ...   ...   ...    ...
# 4    959  4862  8278   4663
# 61   964  4888  8319   4692
# 24   977  4950  8457   4773
# 43   981  4969  8491   4798
# 86   990  5003  8594   4863
#
# [100 rows x 4 columns]

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['size'], df['best'], 'g')
plt.plot(df['size'], df['avg'], 'b')
plt.plot(df['size'], df['worst'], 'r')
plt.plot(df['size'], df['size'] * np.log2(df['size']), 'k--')
plt.legend(['best case', 'avg case', 'worst case', 'reference: nlogn'])
plt.title('Merge Sort')
plt.xlabel('Input Size')
plt.ylabel('Number of Comparisons')
plt.ylim(0, 10000)
plt.xlim(0, 1000)
plt.grid()
plt.savefig('plot.png')
