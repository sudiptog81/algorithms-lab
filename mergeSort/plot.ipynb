# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv")
df = df.sort_values("size")

# %%
df
# Out:
#     size  best   avg  worst
# 35    35    96   142     85
# 45    35    96   142     85
# 95    36   100   147     88
# 7     64   192   305    192
# 9     65   199   316    193
# ..   ...   ...   ...    ...
# 67   943  4797  8125   4552
# 89   960  4864  8288   4672
# 66   970  4919  8395   4727
# 27   979  4960  8487   4785
# 40   997  5033  8666   4910
#
# [100 rows x 4 columns]

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['size'], df['best'], 'g')
plt.plot(df['size'], df['avg'], 'b')
plt.plot(df['size'], df['worst'], 'r')
plt.plot(df['size'], df['size'] * np.log2(df['size']), 'k--')
plt.legend(['best case', 'avg case', 'worst case', 'reference: nlogn'])
plt.title('Merge Sort')
plt.xlabel('Input Size')
plt.ylabel('Number of Comparisons')
plt.ylim(0, 10000)
plt.xlim(0, 1000)
plt.grid()
plt.savefig('plot.png')
