# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv")
df = df.sort_values("size")

# %%
df
# Out:
#     size   best    avg   worst  randomized
# 85    33    164    166     528         202
# 57    48    273    218    1128         270
# 10    50    298    254    1225         264
# 61    65    522    355    2080         342
# 94    68    579    416    2278         390
# ..   ...    ...    ...     ...         ...
# 54   968  52833  11252  468028       11328
# 96   972  53388  10713  471906       10783
# 11   977  54076  10657  476776       10495
# 46   985  55189  10855  484620       10716
# 34   999  57196  11943  498501       10946
#
# [100 rows x 5 columns]

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['size'], df['best'], 'g')
plt.plot(df['size'], df['avg'], 'b')
plt.plot(df['size'], df['worst'], 'r')
plt.plot(df['size'], df['randomized'], 'r--')
plt.plot(df['size'], df['size'] * np.log2(df['size']), 'k--')
plt.plot(df['size'], df['size'] ** 2, 'm--')
plt.legend(['best case', 'avg case', 'worst case', 'randomized', 'reference: nlogn', 'reference: n^2'])
plt.title('Quick Sort')
plt.xlabel('Input Size')
plt.ylabel('Number of Comparisons')
plt.ylim(0, 15000)
plt.xlim(0, 1000)
plt.grid()
plt.savefig('plot.png')
